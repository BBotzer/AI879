# %%
# Imports for functions

from PIL import Image

import skimage as ski
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patches
import cv2 as cv


# Showing the results of scipy computations
import pandas as pd

cv.__version__, ski.__version__
# Out:
# ('4.8.1', '0.22.0')

# %%
im = ski.io.imread('V:\Twitch_Streaming\BotzStream\GlassesandTie.jpg', as_gray=True)
plt.imshow(im, cmap='gray')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\btb51\AppData\Local\Temp\ipykernel_2736\1143379381.py:1: SyntaxWarning: invalid escape sequence '\T'
#   im = ski.io.imread('V:\Twitch_Streaming\BotzStream\GlassesandTie.jpg', as_gray=True)

# %%
im_inv = ski.util.invert(im)
fig = plt.imshow(im_inv, cmap='gray')

fig.axes.get_yaxis().set_visible(False)
fig.axes.get_xaxis().set_visible(False)

plt.savefig('V:\Twitch_Streaming\BotzStream\GlassesandTie_Gray_Invert.png')
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\T'
# <>:7: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\btb51\AppData\Local\Temp\ipykernel_2736\741413134.py:7: SyntaxWarning: invalid escape sequence '\T'
#   plt.savefig('V:\Twitch_Streaming\BotzStream\GlassesandTie_Gray_Invert.png')
